# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percantege'],
#       dtype='object')

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', nrows=2)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', usecols=[0,1])
df
# Out:
#    Student ID  Class
# 0        1001     10
# 1        1002     10
# 2        1003     10
# 3        1004     11
# 4        1005     11
# 5        1006     11
# 6        1007     12
# 7        1008     12
# 8        1009     12
# 9        1010     12

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', skiprows=1)
df
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', skiprows=[2,4]) # using index
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1003     10          3             8                       2
# 2        1005     11          4             7                       2
# 3        1006     11         10             7                       0
# 4        1007     12          4             6                       0
# 5        1008     12         10             6                       2
# 6        1009     12          2             8                       2
# 7        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 4          60
# 2                 0          75
# 3                 0          96
# 4                 0          80
# 5                 0          90
# 6                 4          60
# 7                 0          85

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', index_col='Student ID') # make index to any column
#df=pd.read_csv('D:\Data_sets\student_results.csv', index_col=0)
df
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', header=None)
df
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', header=1)
df
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
# if our dataframe has no heading
df=pd.read_csv('D:\Data_sets\student_results.csv', header=None, prefix="Columns")
df
# Out:
#       Columns0 Columns1   Columns2      Columns3                Columns4  \
# 0   Student ID    Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001       10          2             9                       3
# 2         1002       10          6             8                       2
# 3         1003       10          3             8                       2
# 4         1004       11          0            10                       1
# 5         1005       11          4             7                       2
# 6         1006       11         10             7                       0
# 7         1007       12          4             6                       0
# 8         1008       12         10             6                       2
# 9         1009       12          2             8                       2
# 10        1010       12          6             9                       1
#
#             Columns5    Columns6
# 0   Mobile Games hrs  Percantege
# ...

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', header=None, names=['a','b','c','e','f','g','h'])
df
# Out:
#              a      b          c             e                       f  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    g           h
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df.head()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df.tail()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 5                 0          96
# 6                 0          80
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
df=pd.read_csv('D:\Data_sets\student_results.csv', dtype={'Percantege':'float64'})
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5        45.0
# ...

# %%
df=pd.read_csv('D:\Data_sets\Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     NaN
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 NaN                     NaN
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                    11
# Age                        7
# Annual Income (k$)         6
# Spending Score (1-100)     7
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 31

# %%
df.dropna()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                    40.0
# 5             6  Female  22.0                17.0                    76.0
# ..          ...     ...   ...                 ...                     ...
# 192         193    Male  33.0               113.0                     8.0
# 194         195  Female  47.0               120.0                    16.0
# 196         197  Female  45.0               126.0                    28.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [171 rows x 5 columns]

# %%
df=pd.read_csv('D:\Data_sets\Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     NaN
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female   NaN                16.0                    77.0
# 4             5  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 NaN                     NaN
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.fillna(0)
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     0.0
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female   0.0                16.0                    77.0
# 4             5  Female  31.0                17.0                     0.0
# ..          ...     ...   ...                 ...                     ...
# 195         196       0  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 0.0                     0.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.fillna({'Gender':'none'})
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     NaN
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female   NaN                16.0                    77.0
# 4             5  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196    none  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 NaN                     NaN
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.replace(to_replace=1, value='bhaiya')
# Out:
#     CustomerID  Gender   Age  Annual Income (k$) Spending Score (1-100)
# 0       bhaiya    Male  19.0                15.0                    NaN
# 1            2    Male  21.0                15.0                   81.0
# 2            3  Female  20.0                16.0                    6.0
# 3            4  Female   NaN                16.0                   77.0
# 4            5  Female  31.0                17.0                    NaN
# ..         ...     ...   ...                 ...                    ...
# 195        196     NaN  35.0               120.0                   79.0
# 196        197  Female  45.0               126.0                   28.0
# 197        198    Male  32.0                 NaN                    NaN
# 198        199    Male  32.0               137.0                   18.0
# 199        200    Male  30.0               137.0                   83.0
#
# [200 rows x 5 columns]

# %%
df.replace([1,2,3,4,5],0)
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             0    Male  19.0                15.0                     NaN
# 1             0    Male  21.0                15.0                    81.0
# 2             0  Female  20.0                16.0                     6.0
# 3             0  Female   NaN                16.0                    77.0
# 4             0  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 NaN                     NaN
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.replace({'Age':19.0}, 200)
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  200.0                15.0                     NaN
# 1             2    Male   21.0                15.0                    81.0
# 2             3  Female   20.0                16.0                     6.0
# 3             4  Female    NaN                16.0                    77.0
# 4             5  Female   31.0                17.0                     NaN
# ..          ...     ...    ...                 ...                     ...
# 195         196     NaN   35.0               120.0                    79.0
# 196         197  Female   45.0               126.0                    28.0
# 197         198    Male   32.0                 NaN                     NaN
# 198         199    Male   32.0               137.0                    18.0
# 199         200    Male   30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     NaN
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female   NaN                16.0                    77.0
# 4             5  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0                 NaN                     NaN
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
df.interpolate()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     NaN
# 1             2    Male  21.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  25.5                16.0                    77.0
# 4             5  Female  31.0                17.0                    76.5
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               131.5                    23.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
type(df.Gender[0])
# Out:
# str

# %%
df.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195       NaN
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Gender, Length: 200, dtype: object

# %%
d={'a':1,'b':2}

def fun():
    d['a']=2
    
    
    
fun()
print(d)
# Out:
# {'a': 2, 'b': 2}
