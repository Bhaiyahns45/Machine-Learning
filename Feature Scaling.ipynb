# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from numpy import random

# %%
df=pd.read_csv('D:\Data_sets\Data.csv')
df
# Out:
#     Year_Of_Experience  Salary
# 0                    2      15
# 1                    3      28
# 2                    5      42
# 3                   13      64
# 4                    8      50
# 5                   16      90
# 6                   11      58
# 7                    1       8
# 8                    9      54
# 9                    7      48
# 10                  15      70

# %%
df['Salary']=df.Salary*10000

# %%
df
# Out:
#     Year_Of_Experience  Salary
# 0                    2  150000
# 1                    3  280000
# 2                    5  420000
# 3                   13  640000
# 4                    8  500000
# 5                   16  900000
# 6                   11  580000
# 7                    1   80000
# 8                    9  540000
# 9                    7  480000
# 10                  15  700000

# %%
plt.figure(figsize = (8,6))
plt.scatter(df.Year_Of_Experience, df.Salary, color='r')
plt.xlabel("Year Of Experience",fontsize=15)
plt.ylabel("Salary",fontsize=15)
# Out:
# Text(0, 0.5, 'Salary')

# %%
year=df.loc[:,'Year_Of_Experience']
year=year.values

year
# Out:
# array([ 2,  3,  5, 13,  8, 16, 11,  1,  9,  7, 15], dtype=int64)

# %%
salary=df.loc[:,'Salary']
salary=salary.values

salary
# Out:
# array([150000, 280000, 420000, 640000, 500000, 900000, 580000,  80000,
#        540000, 480000, 700000], dtype=int64)

# %%
def mean_squared_error(y_true, y_predicted):
    cost = np.sum((y_true-y_predicted)**2) / len(y_true)
    return cost

def batch_gradient_descent(x, y, iterations, learning_rate = 0.0001):

    current_weight = 0
    current_bias = 0
    iterations = iterations
    learning_rate = learning_rate
    n = len(x)
#     previous_cost = 0
#     stopping_threshold = 0.0019
    
    
    costs = []
    weights = []

   
    for i in range(iterations):

        y_predicted = (current_weight * x) + current_bias

        current_cost = mean_squared_error(y, y_predicted)
  

        costs.append(current_cost)
        weights.append(current_weight)

        # Calculating the gradients
        weight_gradient = -(2/n) * sum(x * (y-y_predicted))
        bias_gradient = -(2/n) * sum(y-y_predicted)

        # Updating weights and bias
        current_weight = current_weight - (learning_rate * weight_gradient)
        current_bias = current_bias - (learning_rate * bias_gradient)

        
        print(f"Iteration {i+1}: Cost={current_cost}, Weight={current_weight}, Bias={current_bias}")

    plt.figure(figsize = (8,6))
    plt.plot(range(iterations), costs)
    plt.xlabel("Iteration / Epoch",fontsize=15)
    plt.ylabel("Cost",fontsize=15)
    plt.show()

    return current_weight, current_bias




weight, bias = batch_gradient_descent(year, salary, iterations=10000)
print(f"Weight: {weight}\nBias: {bias}")


plt.figure(figsize = (8,6))
plt.scatter(year, salary, marker='o', color='red')



reg_line= [(weight * x ) + bias for x in year]
plt.plot(year,reg_line)


plt.xlabel("Year_Of_Experience",fontsize=15)
plt.ylabel("Salary (1000$)",fontsize=15)
plt.show()
# Out:
# Iteration 1: Cost=281972727272.7273, Weight=1002.5454545454545, Bias=95.81818181818183
# Iteration 2: Cost=271923261234.68973, Weight=1986.6331041322314, Bias=189.97667107438016
# Iteration 3: Cost=262240234237.30353, Weight=2952.6026034604956, Bias=282.5060033879489
# Iteration 4: Cost=252910284194.20215, Weight=3900.787357020873, Bias=373.4361524725178
# Iteration 5: Cost=243920536263.4136, Weight=4831.514634108665, Bias=462.7965404759891
# Iteration 6: Cost=235258585080.1425, Weight=5745.105681721611, Bias=550.6160481302616
# Iteration 7: Cost=226912477637.42834, Weight=6641.875835380153, Bias=636.923024714182
# Iteration 8: Cost=218870696791.05566, Weight=7522.134627908408, Bias=721.7452978331626
# Iteration 9: Cost=211122145365.9517, Weight=8386.185896213408, Bias=805.1101830188368
# Iteration 10: Cost=203656130842.1405, Weight=9234.327886099409, Bias=887.0444931520656
# Iteration 11: Cost=196462350599.11813, Weight=10066.853355153455, Bias=967.5745477125453
# ...

# %% [markdown]
# Iteration 1: Cost=281972727272.7273, Weight=1002.5454545454545, Bias=95.81818181818183
#
# Iteration 2: Cost=271923261234.68973, Weight=1986.6331041322314, Bias=189.97667107438016
#
# Iteration 3: Cost=262240234237.30353, Weight=2952.6026034604956, Bias=282.5060033879489
#
# Iteration 4: Cost=252910284194.20215, Weight=3900.787357020873, Bias=373.4361524725178
#
#
# ##### we can see the cost is too high

# %% [markdown]
# ## Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
df_scaled=sd.fit_transform(df)

# %%
df
# Out:
#     Year_Of_Experience  Salary
# 0                    2  150000
# 1                    3  280000
# 2                    5  420000
# 3                   13  640000
# 4                    8  500000
# 5                   16  900000
# 6                   11  580000
# 7                    1   80000
# 8                    9  540000
# 9                    7  480000
# 10                  15  700000

# %%
df_scaled
# Out:
# array([[-1.25325663, -1.4370285 ],
#        [-1.05052394, -0.86936254],
#        [-0.64505856, -0.25802998],
#        [ 0.97680296,  0.70263548],
#        [-0.03686049,  0.09130292],
#        [ 1.58500103,  1.83796739],
#        [ 0.57133758,  0.44063581],
#        [-1.45598932, -1.74269478],
#        [ 0.1658722 ,  0.26596936],
#        [-0.23959318,  0.00396969],
#        [ 1.38226834,  0.96463515]])

# %%
year=df_scaled[:,0]
salary=df_scaled[:,1]

# %%
def mean_squared_error(y_true, y_predicted):
    cost = np.sum((y_true-y_predicted)**2) / len(y_true)
    return cost

def batch_gradient_descent(x, y, iterations, learning_rate = 0.001):

    current_weight = 0
    current_bias = 0
    iterations = iterations
    learning_rate = learning_rate
    n = len(x)
#     previous_cost = 0
#     stopping_threshold = 0.0019
    
    
    costs = []
    weights = []

   
    for i in range(iterations):

        y_predicted = (current_weight * x) + current_bias

        current_cost = mean_squared_error(y, y_predicted)
  

        costs.append(current_cost)
        weights.append(current_weight)

        # Calculating the gradients
        weight_gradient = -(2/n) * sum(x * (y-y_predicted))
        bias_gradient = -(2/n) * sum(y-y_predicted)

        # Updating weights and bias
        current_weight = current_weight - (learning_rate * weight_gradient)
        current_bias = current_bias - (learning_rate * bias_gradient)

        
        print(f"Iteration {i+1}: Cost={current_cost}, Weight={current_weight}, Bias={current_bias}")

    plt.figure(figsize = (8,6))
    plt.plot(range(iterations), costs)
    plt.xlabel("Iteration / Epoch",fontsize=15)
    plt.ylabel("Cost",fontsize=15)
    plt.show()

    return current_weight, current_bias




weight, bias = batch_gradient_descent(year, salary, iterations=1000)
print(f"Weight: {weight}\nBias: {bias}")


plt.figure(figsize = (8,6))
plt.scatter(year, salary, marker='o', color='red')



reg_line= [(weight * x ) + bias for x in year]
plt.plot(year,reg_line)


plt.xlabel("Year_Of_Experience",fontsize=15)
plt.ylabel("Salary (1000$)",fontsize=15)
plt.show()
# Out:
# Iteration 1: Cost=1.0000000000000002, Weight=0.0019349989924306126, Bias=-2.62416351275037e-19
# Iteration 2: Cost=0.9962595231203933, Weight=0.003866127986876364, Bias=-4.440892098500626e-19
# Iteration 3: Cost=0.9925339931863975, Weight=0.0057933947233332235, Bias=-6.661338147750939e-19
# Iteration 4: Cost=0.9888233504700178, Weight=0.00771680692631717, Bias=-8.276208001751167e-19
# Iteration 5: Cost=0.9851275354819325, Weight=0.009636372304895148, Bias=-1.1304088978001595e-18
# Iteration 6: Cost=0.9814464889705404, Weight=0.01155209855271597, Bias=-1.3928252490751966e-18
# Iteration 7: Cost=0.9777801519210072, Weight=0.013463993348041152, Bias=-1.6148698540002279e-18
# Iteration 8: Cost=0.9741284655543243, Weight=0.015372064353775682, Bias=-1.8167285857502563e-18
# Iteration 9: Cost=0.9704913713263622, Weight=0.017276319217498743, Bias=-2.018587317500285e-18
# Iteration 10: Cost=0.9668688109269351, Weight=0.019176765571494357, Bias=-2.3011895419503247e-18
# ...

# %% [markdown]
# ## Normalization (Min-Max scaling)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler()

# %%
df_minmax=min_max.fit_transform(df)

# %%
df_minmax
# Out:
# array([[0.06666667, 0.08536585],
#        [0.13333333, 0.24390244],
#        [0.26666667, 0.41463415],
#        [0.8       , 0.68292683],
#        [0.46666667, 0.51219512],
#        [1.        , 1.        ],
#        [0.66666667, 0.6097561 ],
#        [0.        , 0.        ],
#        [0.53333333, 0.56097561],
#        [0.4       , 0.48780488],
#        [0.93333333, 0.75609756]])

# %%
year=df_minmax[:,0]
salary=df_minmax[:,1]

# %%
def mean_squared_error(y_true, y_predicted):
    cost = np.sum((y_true-y_predicted)**2) / len(y_true)
    return cost

def batch_gradient_descent(x, y, iterations, learning_rate = 0.01):

    current_weight = 0
    current_bias = 0
    iterations = iterations
    learning_rate = learning_rate
    n = len(x)
#     previous_cost = 0
#     stopping_threshold = 0.0019
    
    
    costs = []
    weights = []

   
    for i in range(iterations):

        y_predicted = (current_weight * x) + current_bias

        current_cost = mean_squared_error(y, y_predicted)
  

        costs.append(current_cost)
        weights.append(current_weight)

        # Calculating the gradients
        weight_gradient = -(2/n) * sum(x * (y-y_predicted))
        bias_gradient = -(2/n) * sum(y-y_predicted)

        # Updating weights and bias
        current_weight = current_weight - (learning_rate * weight_gradient)
        current_bias = current_bias - (learning_rate * bias_gradient)

        
        print(f"Iteration {i+1}: Cost={current_cost}, Weight={current_weight}, Bias={current_bias}")

    plt.figure(figsize = (8,6))
    plt.plot(range(iterations), costs)
    plt.xlabel("Iteration / Epoch",fontsize=15)
    plt.ylabel("Cost",fontsize=15)
    plt.show()

    return current_weight, current_bias




weight, bias = batch_gradient_descent(year, salary, iterations=1000)
print(f"Weight: {weight}\nBias: {bias}")


plt.figure(figsize = (8,6))
plt.scatter(year, salary, marker='o', color='red')



reg_line= [(weight * x ) + bias for x in year]
plt.plot(year,reg_line)


plt.xlabel("Year_Of_Experience",fontsize=15)
plt.ylabel("Salary (1000$)",fontsize=15)
plt.show()
# Out:
# Iteration 1: Cost=0.3148693959223406, Weight=0.006437546193643755, Bias=0.009733924611973392
# Iteration 2: Cost=0.3014190018952185, Weight=0.01273844550456524, Bias=0.019211526349974244
# Iteration 3: Cost=0.28862677828186867, Weight=0.018906074439857225, Bias=0.028439240168904437
# Iteration 4: Cost=0.27646022628018885, Weight=0.02494372510414799, Bias=0.037423339991954435
# Iteration 5: Cost=0.2648884528174874, Weight=0.030854607311105446, Bias=0.04616994273945508
# Iteration 6: Cost=0.2538820912096655, Weight=0.036641850642114636, Bias=0.05468501225693303
# Iteration 7: Cost=0.2434132257407252, Weight=0.04230850645345026, Bias=0.06297436314489176
# Iteration 8: Cost=0.2334553199688982, Weight=0.04785754983323278, Bias=0.0710436644927767
# Iteration 9: Cost=0.2239831485752556, Weight=0.053291881509424495, Bias=0.07889844351952179
# Iteration 10: Cost=0.21497273257976238, Weight=0.05861432971009045, Bias=0.08654408912301449
# ...
